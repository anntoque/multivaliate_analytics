# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_wine = pd.read_csv('winequality-red.csv', sep=';')
df_wine.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
from sklearn import linear_model

# %% [markdown]
# #  Simple Liner Regression

# %%
clf = linear_model.LinearRegression()

X = df_wine.loc[:, ['density']].values
Y = df_wine['alcohol'].values

# make predict model
clf.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print('Regression coefficient: ' + str(clf.coef_))
print('intercept: ' + str(clf.intercept_))
print('coefficient od determination ' + str(clf.score(X,Y)))
print('alcohol = ' + str(clf.coef_) + '* density + ' + str(clf.score(X,Y)))
# Out:
# Regression coefficient: [-280.16382307]
# intercept: 289.675343383
# coefficient od determination 0.246194364397
# alcohol = [-280.16382307]* density + 0.246194364397

# %%
plt.scatter(X,Y,color='black')
plt.plot(X, clf.predict(X))

# %% [markdown]
# # Multiple regression analytics

# %%
wine_except_quality = df_wine.drop('quality', axis=1)
X = wine_except_quality.values
Y = df_wine['quality'].values

# %%
clf.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
df=pd.DataFrame({'Name': wine_except_quality.columns, 
                   'Coefficients': clf.coef_}).sort_values(by='Coefficients')
print('intercept_: ' + str(clf.intercept_))
print('coefficient of determination: ' + str(clf.score(X,Y)))
# Out:
# intercept_: 21.9652084495
# coefficient of determination: 0.360551703039

# %%
df
# Out:
#                     Name  Coefficients
# 7                density    -17.881164
# 4              chlorides     -1.874225
# 1       volatile acidity     -1.083590
# 8                     pH     -0.413653
# 2            citric acid     -0.182564
# 6   total sulfur dioxide     -0.003265
# 5    free sulfur dioxide      0.004361
# 3         residual sugar      0.016331
# 0          fixed acidity      0.024991
# 10               alcohol      0.276198
# 9              sulphates      0.916334

# %% [markdown]
# # standardization

# %%
from sklearn.preprocessing import StandardScaler
X_standard = StandardScaler().fit_transform(X)
Y_standard = StandardScaler().fit_transform(Y)
# Out:
# /Users/Yasutaka/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)

# %%
clf = linear_model.LinearRegression()
clf.fit(X_standard,Y_standard)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
df=pd.DataFrame({'Name': wine_except_quality.columns, 
                   'Coefficients': clf.coef_}).sort_values(by='Coefficients')
print('intercept_: ' + str(round(clf.intercept_)))
print('coefficient of determination: ' + str(round(clf.score(X,Y))))
# Out:
# intercept_: 0.0
# coefficient of determination: -97.0

# %%
df
# Out:
#                     Name  Coefficients
# 1       volatile acidity     -0.240261
# 6   total sulfur dioxide     -0.132979
# 4              chlorides     -0.109230
# 8                     pH     -0.079080
# 2            citric acid     -0.044038
# 7                density     -0.041789
# 3         residual sugar      0.028513
# 0          fixed acidity      0.053879
# 5    free sulfur dioxide      0.056491
# 9              sulphates      0.192336
# 10               alcohol      0.364470

# %% [markdown]
# # Statsmodels
# ref: http://wcs.hatenablog.com/entry/2016/11/08/231703

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df_wine, figsize=(15,15))
plt.show()

# %%
import statsmodels.api as sm

mod = sm.OLS(Y, sm.add_constant(X))
res = mod.fit()
